# %% [markdown]
# # --- Day 3: Gear Ratios ---
# You and the Elf eventually reach a gondola lift station; he says the gondola lift will take you up to the water source, but this is as far as he can bring you. You go inside.
#
# It doesn't take long to find the gondolas, but there seems to be a problem: they're not moving.
#
# "Aaah!"
#
# You turn around to see a slightly-greasy Elf with a wrench and a look of surprise. "Sorry, I wasn't expecting anyone! The gondola lift isn't working right now; it'll still be a while before I can fix it." You offer to help.
#
# The engineer explains that an engine part seems to be missing from the engine, but nobody can figure out which one. If you can add up all the part numbers in the engine schematic, it should be easy to work out which part is missing.
#
# The engine schematic (your puzzle input) consists of a visual representation of the engine. There are lots of numbers and symbols you don't really understand, but apparently any number adjacent to a symbol, even diagonally, is a "part number" and should be included in your sum. (Periods (.) do not count as a symbol.)
#
# Here is an example engine schematic:
#
# 467..114.. ......... ..35..633. ......#... 617...... .....+.58. ..592..... ......755. ...$.*.... .664.598.. In this schematic, two numbers are not part numbers because they are not adjacent to a symbol: 114 (top right) and 58 (middle right). Every other number is adjacent to a symbol and so is a part number; their sum is 4361.
#
# Of course, the actual engine schematic is much larger. What is the sum of all of the part numbers in the engine schematic?
#
# Your puzzle answer was 512794.
#
# ## --- Part Two ---
# The engineer finds the missing part and installs it in the engine! As the engine springs to life, you jump in the closest gondola, finally ready to ascend to the water source.
#
# You don't seem to be going very fast, though. Maybe something is still wrong? Fortunately, the gondola has a phone labeled "help", so you pick it up and the engineer answers.
#
# Before you can explain the situation, she suggests that you look out the window. There stands the engineer, holding a phone in one hand and waving with the other. You're going so slowly that you haven't even left the station. You exit the gondola.
#
# The missing part wasn't the only issue - one of the gears in the engine is wrong. A gear is any * symbol that is adjacent to exactly two part numbers. Its gear ratio is the result of multiplying those two numbers together.
#
# This time, you need to find the gear ratio of every gear and add them all up so that the engineer can figure out which gear needs to be replaced.
#
# Consider the same engine schematic again:
#
# 467..114.. ......... ..35..633. ......#... 617...... .....+.58. ..592..... ......755. ...$.*.... .664.598.. In this schematic, there are two gears. The first is in the top left; it has part numbers 467 and 35, so its gear ratio is 16345. The second gear is in the lower right; its gear ratio is 451490. (The * adjacent to 617 is not a gear because it is only adjacent to one part number.) Adding up all of the gear ratios produces 467835.
#
# What is the sum of all of the gear ratios in your engine schematic?
#
# Your puzzle answer was 67779080.

# %%
#Boilerplate 2 

individuals = []

with open('./input.txt', 'r') as file:
    file_content = file.read().strip()  # Read the file content and remove leading/trailing whitespaces

# Split the content based on empty lines
individual_strings = file_content.split('\n\n')

# Process each individual
for i, individual_str in enumerate(individual_strings, 1):
    # Convert lines to integers and add them to the individuals list
    individual = [int(line) for line in individual_str.split('\n')]
    individuals.append(individual)
    print(f"Individual {i}: {individual}")

# Example: Print all individuals
print("All Individuals:")
for i, individual in enumerate(individuals, 1):
    print(f"Individual {i}: {individual}")

# %%
import re

individuals = []

with open('./input.txt', 'r') as file:
    file_content = file.read().strip()  # Read the file content and remove leading/trailing whitespaces

# Split the content based on empty lines
individual_strings = file_content.split('\n')

# Process each individual
for i, individual_str in enumerate(individual_strings, 1):
    # Convert lines to integers and add them to the individuals list
    individual = [line for line in re.split( '',individual_str)]
    
    individuals.append(individual)
   # print(f"Game {i}: {individual}")
# Example: Print all individuals
for i, individual in enumerate(individuals, 1):
    print(individual)
# Out:
# ['', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '4', '4', '1', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '3', '6', '7', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '2', '9', '6', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '5', '6', '7', '.', '.', '4', '7', '.', '.', '.', '.', '.', '4', '5', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '9', '4', '7', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '']
# ...

# %%
for i in range(0,len(individuals)):
    del individuals[i][0]
    del individuals[i][-1]
individuals
# Out:
# [['.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '4',
#   '4',
#   '1',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '3',
#   '6',
#   '7',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '2',
#   '9',
#   '6',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '5',
#   '6',
#   '7',
#   '.',
#   '.',
#   '4',
#   '7',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   '4',
#   '5',
#   '.',
#   '.',
#   '.',
#   '.',
# ...

# %%
coun=0
numbers = []
special = "!@#$%^&*()-+?_=,<>/"
for i in range(0, len(individuals)):
    j=0
    while j<(len(individuals[i])-1):
        if individuals[i][j].isdigit():
            #get the number
            l=0
            number = int(individuals[i][j]) 
            #print(individuals[i][j])
            if individuals[i][j+1].isdigit():
                l=l+1
                #print(individuals[i][j+1])
                number = concat(number, individuals[i][j+1])
                if individuals[i][j+2].isdigit():
                    l=l+1
                    #print(individuals[i][j+2])
                    number = concat(number, individuals[i][j+2])
                
            #check the spaces around it 
            y=j-1
            if y<0:
                y=0
            check = False
            while y<=j+1+l and y<len(individuals[i]):
                #print(y)
                if i>0:
                    if (individuals[i-1][y]) in special:
                        check = True
                        #print(individuals[i-1][y])
                if individuals[i][j-1] in special:
                    check = True
                
                if (j+l) < (len(individuals[i]) - 1) and individuals[i][j+l+1] in special:
                    check = True
                    #print(individuals[i-1][y])
                if i<(len(individuals)-1):
                    if (individuals[i+1][y]) in special:
                        check = True
                y=y+1
            if check ==True:
                numbers.append(number)
                coun = coun + number
            j=j+l
        j=j+1

coun
# Out:
# 512794

# %%
def concat(a, b): 
    s1 = str(a) 
    s2 = str(b) 
    s = s1 + s2 
    c = int(s) 
    return c

# %%
numbers[-5:]
# Out:
# [473, 571, 720, 269, 902]

# %%
sumo = 0
for i in range (0, len(numbers)):
    sumo = sumo + numbers[i]

# %%
sumo
# Out:
# 512794

# %%
sum +571+ 720+269.

# %%
sum

# %%
# Out:
# True

# %%
coun=0
numbers = []

for i in range(0, len(individuals)):
    j=0
    while j<(len(individuals[i])-1):
        if individuals[i][j].isdigit():
            #get the number
            l=0
            number = int(individuals[i][j]) 
            #print(individuals[i][j])
            if individuals[i][j+1].isdigit():
                
                #print(individuals[i][j+1])
                number = concat(number, individuals[i][j+1])
                if individuals[i][j+2].isdigit():
                    
                    #print(individuals[i][j+2])
                    number = concat(number, individuals[i][j+2])
            if (j-1)>=0 and individuals[i][j-1].isdigit():
                
                #print(individuals[i][j+1])
                number = concat(individuals[i][j+1], number)
                if (j-2)>=0 and individuals[i][j-2].isdigit():
                    
                    #print(individuals[i][j+2])
                    number = concat(individuals[i][j+2], number)
           
        
            #check the spaces around it 
            y=j-1
            if y<0:
                y=0
            check = 0
            while y<=j+1 and y<len(individuals[i]):
                #print(y)
                
                if i>0:
                    if (individuals[i-1][y]).isdigit():
                        check = check+1
                        #print(individuals[i-1][y])
                        number = int(individuals[i][j]) 
                        #print(individuals[i][j])
                        if individuals[i][j+1].isdigit():
                
                            #print(individuals[i][j+1])
                            number = concat(number, individuals[i][j+1])
                            if individuals[i][j+2].isdigit():
                    
                                #print(individuals[i][j+2])
                                number = concat(number, individuals[i][j+2])
                        if (j-1)>=0 and individuals[i][j-1].isdigit():
                
                            #print(individuals[i][j+1])
                            number = concat(individuals[i][j+1], number)
                            if (j-2)>=0 and individuals[i][j-2].isdigit():
                    
                                #print(individuals[i][j+2])
                                number = concat(individuals[i][j+2], number)
                
                
                if individuals[i][j-1].isdigit():
                    check = check+1
                     #print(individuals[i-1][y])
                    number = int(individuals[i][j]) 
                    #print(individuals[i][j])
                    if individuals[i][j+1].isdigit():
                
                        #print(individuals[i][j+1])
                        number = concat(number, individuals[i][j+1])
                        if individuals[i][j+2].isdigit():
                    
                            #print(individuals[i][j+2])                             
                            number = concat(number, individuals[i][j+2])
                    if (j-1)>=0 and individuals[i][j-1].isdigit():
                
                        #print(individuals[i][j+1])
                        number = concat(individuals[i][j+1], number)
                        if (j-2)>=0 and individuals[i][j-2].isdigit():
                    
                            #print(individuals[i][j+2])
                            number = concat(individuals[i][j+2], number)
                
                
                if (j+l) < (len(individuals[i]) - 1) and individuals[i][j+l+1].isdigit():
                    check = check+1
                    #print(individuals[i-1][y])
                    number = int(individuals[i][j]) 
                    #print(individuals[i][j])
                    if individuals[i][j+1].isdigit():
                
                        #print(individuals[i][j+1])
                        number = concat(number, individuals[i][j+1])
                        if individuals[i][j+2].isdigit():
                    
                            #print(individuals[i][j+2])                             
                            number = concat(number, individuals[i][j+2])
                    if (j-1)>=0 and individuals[i][j-1].isdigit():
                
                        #print(individuals[i][j+1])
                        number = concat(individuals[i][j+1], number)
                        if (j-2)>=0 and individuals[i][j-2].isdigit():
                    
                            #print(individuals[i][j+2])
                            number = concat(individuals[i][j+2], number)
                
                
                if i<(len(individuals)-1):
                    if (individuals[i+1][y]).isdigit():
                        check = check+1
                        number = int(individuals[i][j]) 
                        #print(individuals[i][j])
                        if individuals[i][j+1].isdigit():
                
                            #print(individuals[i][j+1])
                            number = concat(number, individuals[i][j+1])
                            if individuals[i][j+2].isdigit():
                    
                                #print(individuals[i][j+2])                             
                                number = concat(number, individuals[i][j+2])
                        if (j-1)>=0 and individuals[i][j-1].isdigit():
                
                            #print(individuals[i][j+1])
                            number = concat(individuals[i][j+1], number)
                            if (j-2)>=0 and individuals[i][j-2].isdigit():
                    
                                #print(individuals[i][j+2])
                                number = concat(individuals[i][j+2], number)
                        numbers.append(number)
               
                y=y+1
            
            
            if check >1:
                numbers.append(num1*num2)
                coun = coun + (num1*num2)
            
        j=j+1

coun

# %%
coord = []
coords =[]
coun=0
numbers = []
special = "*"
for i in range(0, len(individuals)):
    j=0
    while j<(len(individuals[i])-1):
        if individuals[i][j].isdigit():
            #get the number
            l=0
            number = int(individuals[i][j]) 
            #print(individuals[i][j])
            if individuals[i][j+1].isdigit():
                l=l+1
                #print(individuals[i][j+1])
                number = concat(number, individuals[i][j+1])
                if individuals[i][j+2].isdigit():
                    l=l+1
                    #print(individuals[i][j+2])
                    number = concat(number, individuals[i][j+2])
                
            #check the spaces around it 
            y=j-1
            if y<0:
                y=0
            coord = []
            check = False
            while y<=j+1+l and y<len(individuals[i]):
                
                #print(y)
                if i>0:
                    if (individuals[i-1][y]) in special:
                        check = True
                        coord.append([i-1,y])
                        #print(individuals[i-1][y])
                if individuals[i][j-1] in special:
                    check = True
                    coord.append([i,j-1])
                if (j+l) < (len(individuals[i]) - 1) and individuals[i][j+l+1] in special:
                    check = True
                    coord.append([i,j+l+1])
                    #print(individuals[i-1][y])
                if i<(len(individuals)-1):
                    if (individuals[i+1][y]) in special:
                        check = True
                        coord.append([i+1,y])
                y=y+1
            if check ==True:
                numbers.append(number)
                coun = coun + number
                coords.append(coord)
            j=j+l
        j=j+1

coun
# Out:
# 308238

# %%
len(coord)
# Out:
# 0

# %%
len(numbers)
# Out:
# 653

# %%
len(coords)
# Out:
# 653

# %%
coords
# Out:
# [[[1, 53]],
#  [[1, 104]],
#  [[2, 4]],
#  [[2, 16]],
#  [[1, 53], [1, 53], [1, 53], [1, 53], [1, 53]],
#  [[2, 85]],
#  [[2, 118]],
#  [[2, 132]],
#  [[3, 70]],
#  [[1, 104]],
#  [[3, 120]],
#  [[2, 4]],
#  [[2, 16]],
#  [[4, 75]],
#  [[2, 118]],
#  [[2, 132]],
#  [[5, 29]],
#  [[5, 96]],
#  [[3, 120]],
#  [[6, 4]],
#  [[5, 29], [5, 29], [5, 29], [5, 29], [5, 29]],
#  [[4, 54]],
#  [[6, 74]],
#  [[6, 113]],
#  [[7, 39]],
#  [[5, 96]],
#  [[6, 4]],
#  [[7, 30], [7, 30], [7, 30], [7, 30], [7, 30]],
#  [[6, 74]],
#  [[8, 106]],
#  [[6, 113]],
#  [[6, 127]],
#  [[6, 127]],
#  [[7, 30]],
#  [[7, 39]],
#  [[9, 85]],
#  [[10, 27]],
#  [[8, 48]],
#  [[8, 106]],
#  [[11, 32]],
#  [[10, 37], [10, 37], [10, 37], [10, 37], [10, 37]],
#  [[10, 37], [10, 37], [10, 37], [10, 37], [10, 37]],
#  [[11, 62]],
#  [[9, 85]],
#  [[12, 10]],
#  [[12, 20]],
#  [[10, 27]],
#  [[12, 45]],
#  [[12, 98]],
#  [[12, 108]],
#  [[12, 123]],
#  [[12, 123]],
#  [[12, 10], [12, 10], [12, 10], [12, 10], [12, 10]],
# ...

# %%
for i in range(0,30):
    for i in range(0, len(coords)):
        if len(coords[i])>1:
            del coords[i][-1]

# %%
len(coords)
# Out:
# 653

# %%
s=0
for i in range (0,653):
    for j in range(i+1,653):
        if coords[i][0]==coords[j][0]:
            s= s+ (numbers[i]*numbers[j])

# %%
s
# Out:
# 67779080

# %%
numbers[2]
# Out:
# 606

# %%
coords[2][0]
# Out:
# [2, 4]

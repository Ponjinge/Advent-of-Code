# %%
#Boilerplate 1 

s = []

with open('./test.txt', 'r') as file:
    file_content = file.read().strip()  
individual_strings = file_content.split('\n')
for i, individual_str in enumerate(individual_strings, 1):
    word = [*individual_str]
    s.append(word)

# %%
for i in range(len(s)):
    for j in range(len(s[0])):
        s[i][j]= int(s[i][j])

# %%
def nv(t):
    return cool[dir_numerate(t[0])][t[1]][t[2]]

# %%
def dir(way,i,j):
    if way =='U':
        return((way, i-1,j)) 
    if way =='D':
        return((way, i+1,j))
    if way =='L':
        return((way, i,j-1))
    if way =='R':
        return((way, i,j+1))

# %%
def record_move(way, i, j, new):
    
    if new == False:
        prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].pop(0)
        prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].pop(0)
        prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].pop(0)
        
    prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].append(prevmoves[d][i][j][1])
    prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].append(prevmoves[d][i][j][2])
    prevmoves[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]].append(way)

# %%
def dir_translate(d):
    if d ==0:
        return 'U'
    elif d ==1:
        return 'D'
    elif d ==2:
        return 'L'
    elif d ==3:
        return 'R'

# %%
def dir_numerate(way):
    if way =='U':
        return 0 
    if way =='D':
        return 1
    if way =='L':
        return 2
    if way =='R':
        return 3

# %%
#Initiation

start = ('U',0,0) # Starting position 

ol = [start] # Open List
cl = [] # Closed List 
c=0 # Same direction count 


# Create an empty table for the cost to move to a space 
cool = [[[[]for _ in range(len(s))] for _ in range(len(s))] for _ in range(4)]

# Create an empty table for the 3 previous directions to get to a space
prevmoves = [[[[]for _ in range(len(s))] for _ in range(len(s))] for _ in range(4)]

# We start at 0 with no real previous directions
cool[0][0][0]=0
cool[1][0][0]=0
cool[2][0][0]=0
cool[3][0][0]=0
prevmoves[0][0][0]=['A','B','C']
prevmoves[1][0][0]=['A','B','C']
prevmoves[2][0][0]=['A','B','C']
prevmoves[3][0][0]=['A','B','C']

# While there are elements in the open list 
while ol:
    
    #print(ol)
    
    min = 10**10 
    for i in range (len(ol)):
        
        # We treat the lowest cost element in the list
        if nv(ol[i])<min:
            min = nv(ol[i])
            min_index = i
    active = ol[min_index] # It becomes the active space 
    
    # We remove it from the open list and add it to the closed list
    cl.append(active)
    ol.pop(min_index) 
    
    d = dir_numerate(active[0])
    i = active[1]
    j= active[2]
    
    
    # For each possible direction around that space
    
    directions = ['U','D','L','R']
    
    if prevmoves[d][i][j][2] == prevmoves[d][i][j][1] == prevmoves[d][i][j][0]:
        directions.remove(prevmoves[d][i][j][2])
   
    if prevmoves[d][i][j][2] == 'U':
        directions.remove('D')
    if prevmoves[d][i][j][2] == 'D':
        directions.remove('U')
    if prevmoves[d][i][j][2] == 'R':
        directions.remove('L')
    if prevmoves[d][i][j][2] == 'L':
        directions.remove('R')


    for way in  directions :
        
        #print( i, j , way)
        #print(prevmoves[i][j])
        #print(dir(way, i, j))
      
        
       
        # If this square is already in the Open List for this direction
        if dir(way,i,j) in ol:
            
            
            if cool[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]] >= s[dir(way,i,j)[1]][dir(way,i,j)[2]] + cool[d][i][j]:
                    
                cool[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]] = s[dir(way,i,j)[1]][dir(way,i,j)[2]] + cool[d][i][j]
                  
                #Move recording (works)
                record_move(way, i, j, False)
                    
                    
        # If this square is already in the Closed List for this direction            
        elif dir(way,i,j) in cl:
            
            if cool[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]] >= s[dir(way,i,j)[1]][dir(way,i,j)[2]] + cool[d][i][j]:
                      
                cool[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]] = s[dir(way,i,j)[1]][dir(way,i,j)[2]] + cool[d][i][j]
                    
                # Add to open list
                ol.append(dir(way,i,j))
                    
                # Move recording (works)   
                record_move(way, i, j, False)
                    
                    
        # If this space has not been observed yet from this direction           
        elif 0 <= dir(way,i,j)[1] < len(s) and 0 <= dir(way,i,j)[2] < len(s[0]):
           
            cool[dir_numerate(way)][dir(way,i,j)[1]][dir(way,i,j)[2]] = s[dir(way,i,j)[1]][dir(way,i,j)[2]] + cool[d][i][j]

            # Add to open list
            ol.append(dir(way,i,j))
                
            #Move recording (works)
            record_move(way, i, j, True)

# %%
cool
# Out:
# [[[0, 9, 7, 14, 19, 23, 31, 34, 35, 40, 50, 49, 49],
#   [13, 10, 13, 21, 22, 26, 29, 37, 45, 48, 51, 52, 55],
#   [17, 15, 20, 26, 28, 34, 39, 45, 48, 52, 54, 59, 59],
#   [23, 27, 24, 31, 36, 41, 45, 54, 56, 61, 64, 62, 65],
#   [31, 28, 30, 36, 41, 49, 57, 61, 68, 73, 71, 66, 72],
#   [32, 31, 35, 42, 47, 58, 63, 71, 79, 84, 79, 83, 78],
#   [40, 44, 41, 49, 57, 63, 69, 80, 86, 92, 93, 86, 92],
#   [46, 50, 47, 51, 61, 66, 76, 87, 93, 101, 102, 95, 98],
#   [57, 53, 58, 54, 63, 67, 77, 96, 103, 106, 105, 111, 103],
#   [54, 61, 57, 59, 64, 73, 81, 93, 98, 101, 108, 110, 105],
#   [57, 59, 60, 65, 69, 75, 81, 91, 103, 109, 114, 113, 116],
#   [63, 64, 63, 65, 70, 76, 86, 92, 97, 115, 119, 113, 118],
#   [[], [], [], [], [], [], [], [], [], [], [], [], []]],
#  [[0, [], [], [], [], [], [], [], [], [], [], [], []],
#   [3, 6, 6, 13, 22, 26, 26, 39, 38, 41, 45, 43, 55],
#   [6, 7, 11, 16, 17, 24, 31, 37, 39, 43, 47, 48, 50],
#   [9, 11, 15, 22, 22, 29, 31, 40, 43, 48, 49, 53, 52],
#   [18, 16, 19, 27, 28, 34, 38, 47, 49, 55, 54, 57, 58],
#   [19, 27, 22, 33, 36, 42, 46, 53, 61, 64, 58, 62, 67],
#   [23, 27, 27, 37, 43, 49, 56, 62, 69, 71, 73, 68, 72],
#   [34, 33, 35, 41, 50, 56, 62, 71, 76, 80, 79, 83, 75],
#   [38, 39, 40, 45, 58, 62, 69, 80, 86, 91, 87, 88, 82],
#   [42, 49, 46, 48, 59, 66, 78, 87, 94, 97, 100, 93, 98],
#   [54, 49, 55, 52, 60, 69, 76, 95, 100, 102, 102, 99, 99],
#   [52, 54, 55, 58, 63, 70, 80, 92, 98, 102, 109, 108, 104],
#   [56, 57, 57, 63, 69, 74, 79, 89, 103, 107, 114, 110, 107]],
#  [[11, 11, 15, 22, 27, 34, 36, 38, 41, 51, 52, 51, []],
#   [9, 8, 14, 27, 30, 31, 40, 43, 44, 50, 49, 57, []],
#   [10, 13, 21, 22, 26, 35, 42, 45, 48, 51, 50, 55, []],
#   [14, 19, 26, 28, 34, 39, 45, 51, 52, 54, 57, 57, []],
#   [20, 24, 31, 34, 40, 43, 54, 57, 61, 61, 62, 61, []],
#   [27, 26, 36, 44, 47, 55, 61, 68, 73, 66, 66, 72, []],
#   [31, 31, 42, 50, 57, 63, 68, 78, 79, 80, 75, 78, []],
#   [36, 41, 44, 57, 64, 69, 78, 85, 87, 88, 86, 80, []],
#   [43, 46, 50, 62, 71, 75, 87, 95, 99, 93, 96, 90, []],
#   [53, 51, 54, 63, 72, 85, 96, 103, 105, 103, 97, 103, []],
#   [50, 56, 54, 64, 75, 84, 97, 108, 108, 107, 104, 105, []],
#   [56, 60, 62, 69, 75, 84, 100, 105, 110, 116, 114, 107, []],
#   [61, 60, 65, 71, 80, 86, 93, 109, 112, 119, 115, 110, []]],
#  [[0, 4, 5, 8, 18, 21, 23, 34, 35, 36, 39, 41, 52],
#   [[], 5, 6, 11, 15, 20, 29, 31, 34, 39, 47, 47, 46],
#   [[], 8, 12, 16, 18, 21, 26, 32, 42, 43, 45, 50, 52],
#   [[], 13, 15, 21, 26, 30, 34, 39, 43, 48, 52, 54, 55],
#   [[], 23, 20, 25, 31, 33, 40, 46, 52, 56, 60, 57, 63],
#   [[], 23, 26, 30, 35, 44, 50, 53, 62, 69, 68, 63, 66],
#   [[], 27, 32, 34, 42, 49, 55, 64, 70, 76, 78, 79, 74],
#   [[], 40, 36, 42, 49, 56, 63, 71, 78, 85, 86, 84, 86],
#   [[], 44, 44, 44, 53, 59, 69, 78, 86, 92, 99, 95, 95],
#   [[], 47, 53, 50, 54, 61, 70, 87, 95, 100, 101, 105, 96],
#   [[], 56, 51, 55, 58, 66, 72, 84, 90, 95, 107, 108, 102],
#   [[], 57, 58, 61, 63, 67, 75, 83, 100, 104, 109, 112, 113],
#   [[], 59, 59, 59, 65, 72, 78, 84, 89, 108, 112, 115, 113]]]
